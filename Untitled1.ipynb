# %%
import sys
sys.path.insert(0, r'C:\Users\lam ngoe\OneDrive\Desktop\MFE Work Project Option Index Pricing\Falling Knives\ZigZag')
from ZigZag import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\lam ngoe\OneDrive\Desktop\MFE Work Project Option Index Pricing\Falling Knives\ZigZag')
# ----> 3 from ZigZag import *
#
# File ~\OneDrive\Desktop\MFE Work Project Option Index Pricing\Falling Knives\ZigZag\__init__.py:1
# ----> 1 from .zigzag.core import *
#       3 PEAK = 1
#       4 VALLEY = -1
#
# File ~\OneDrive\Desktop\MFE Work Project Option Index Pricing\Falling Knives\ZigZag\zigzag\__init__.py:1
# ----> 1 from .core import *
#       3 PEAK = 1
#       4 VALLEY = -1
#
# ModuleNotFoundError: No module named 'ZigZag.zigzag.core'
